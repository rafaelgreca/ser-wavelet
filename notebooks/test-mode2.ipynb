# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(
                  os.path.dirname("test-mode2"), 
                  os.pardir)
)
sys.path.append(PROJECT_ROOT)

import pandas as pd
import numpy as np
import torch
import json
import random
import torch.nn as nn
import torch.nn.functional as F
from train import train, evaluate
from src.dataset import create_dataloader
from src.data_augmentation import Mixup
from src.utils import feature_extraction_pipeline, read_features_files, choose_model, read_feature
from src.models.utils import SaveBestModel, weight_init
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import StepLR
from typing import Dict, Tuple, List
from sklearn.metrics import classification_report

# making sure the experiments are reproducible
seed = 2109
random.seed(seed)
np.random.seed(seed)
torch.cuda.manual_seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

def seed_worker(worker_id: int):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(seed)

# %%
features_path = "../features/propor2022/"

# loading training features
X_train = read_feature(path=features_path, fold="0", name="X_train.pth")
y_train = read_feature(path=features_path, fold="0", name="y_train.pth")
print(f"Train: {X_train.shape}, {y_train.shape}")

# loading validation features
X_valid = read_feature(path=features_path, fold="0", name="X_valid.pth")
y_valid = read_feature(path=features_path, fold="0", name="y_valid.pth")
print(f"Valid: {X_valid.shape}, {y_valid.shape}")

# loading testing features
X_test = read_feature(path=features_path, fold=None, name="X_test.pth")
y_test = read_feature(path=features_path, fold=None, name="y_test.pth")
print(f"Test: {X_test.shape}, {y_test.shape}")
# Out:
# Train: torch.Size([500, 1, 128000]), torch.Size([500, 3])
# Valid: torch.Size([125, 1, 128000]), torch.Size([125, 3])
# Test: torch.Size([308, 1, 128000]), torch.Size([308, 3])

# %%
# reading the parameters configuration file
params = json.load(open("../config/mode_2.json", "r"))

# parameters defination
k_fold = None
max_seconds = 16

if "kfold" in params.keys():
    k_fold = params["kfold"]["num_k"]

max_samples = max_seconds * int(params["sample_rate"])

feature_config = params["feature"]
feature_config["sample_rate"] = int(params["sample_rate"])
data_augmentation_config = params["data_augmentation"]
dataset = params["dataset"]
wavelet_config = params["wavelet"]
model_config = params["model"]
mode = params["mode"]

feat_path = os.path.join(params["output_path"], params["dataset"])

if dataset == "propor2022":
    if data_augmentation_config["target"] == "majority":
        data_augment_target = [0]
    elif data_augmentation_config["target"] == "minority":
        data_augment_target = [1, 2]
    elif data_augmentation_config["target"] == "all":
        data_augment_target = [0, 1, 2]
    else:
        raise ValueError("Invalid arguments for target. Should be 'all', 'majority' or 'minority")
else:
    raise NotImplementedError

# %%
# creating and defining the model
device = torch.device("cuda" if torch.cuda.is_available and model_config["use_gpu"] else "cpu")

model = choose_model(
    mode=mode,
    model_name=model_config["name"],
    device=device
)

optimizer = torch.optim.Adam(
    params=model.parameters(),
    lr=model_config["learning_rate"],
    betas=(0.9, 0.98),
    eps=1e-9
)
loss = torch.nn.CrossEntropyLoss()
scheduler = None
mixer = None

# creating the model checkpoint object
sbm = SaveBestModel(
    output_dir=os.path.join(model_config["output_path"], dataset, mode, model_config["name"]),
    model_name=model_config["name"]
)

if model_config["use_lr_scheduler"]:
    scheduler = StepLR(optimizer, step_size=10, gamma=0.1)

if "mixup" in data_augmentation_config["techniques"].keys():
    mixer = Mixup(
        alpha=data_augmentation_config["techniques"]["mixup"]["alpha"]
    )
    
# creating the training dataloader
training_dataloader = create_dataloader(
    X=X_train,
    y=y_train,
    feature_config=feature_config,
    wavelet_config=wavelet_config,
    data_augmentation_config=data_augmentation_config,
    num_workers=0,
    mode=mode,
    shuffle=False,
    training=True,
    batch_size=model_config["batch_size"],
    data_augment_target=data_augment_target,
    worker_init_fn=seed_worker,
    generator=g
)

# creating the validation dataloader
validation_dataloader = create_dataloader(
    X=X_valid,
    y=y_valid,
    feature_config=feature_config,
    wavelet_config=wavelet_config,
    data_augmentation_config=data_augmentation_config,
    num_workers=0,
    mode=mode,
    shuffle=False,
    training=False,
    batch_size=model_config["batch_size"],
    data_augment_target=data_augment_target,
    worker_init_fn=seed_worker,
    generator=g
)

# training loop
for epoch in range(1, model_config["epochs"] + 1):
    print(f"Epoch: {epoch}/{model_config['epochs']}")

    train_f1, train_loss = train(
        device=device,
        dataloader=training_dataloader,
        optimizer=optimizer,
        model=model,
        loss=loss,
        mixer=mixer
    )

    valid_f1, valid_loss = evaluate(
        device=device,
        dataloader=validation_dataloader,
        model=model,
        loss=loss
    )

    print(f"\nEpoch: {epoch}")
    print(f"Train F1-Score: {train_f1:1.6f}")
    print(f"Train Loss: {train_loss:1.6f}")
    print(f"Validation F1-Score: {valid_f1:1.6f}")
    print(f"Validation Loss: {valid_loss:1.6f}\n")

    # updating learning rate
    if not scheduler is None:
        scheduler.step()
# Out:
# Epoch: 1/100
#
# Epoch: 1
# Train F1-Score: 0.338125
# Train Loss: 189.348260
# Validation F1-Score: 0.068995
# Validation Loss: 229.364964
#
# Epoch: 2/100
#
# Epoch: 2
# Train F1-Score: 0.305387
# Train Loss: 38.368960
# Validation F1-Score: 0.294643
# Validation Loss: 81.405603
#
# Epoch: 3/100
#
# Epoch: 3
# Train F1-Score: 0.319792
# Train Loss: 30.468149
# Validation F1-Score: 0.294643
# Validation Loss: 81.763507
#
# Epoch: 4/100
#
# Epoch: 4
# Train F1-Score: 0.332648
# Train Loss: 26.957206
# Validation F1-Score: 0.294643
# Validation Loss: 43.910236
#
# Epoch: 5/100
#
# Epoch: 5
# Train F1-Score: 0.338144
# Train Loss: 22.585745
# Validation F1-Score: 0.294643
# Validation Loss: 29.454572
#
# Epoch: 6/100
#
# Epoch: 6
# Train F1-Score: 0.358662
# Train Loss: 18.571579
# Validation F1-Score: 0.316142
# Validation Loss: 26.057856
#
# Epoch: 7/100
#
# Epoch: 7
# Train F1-Score: 0.314514
# Train Loss: 14.286450
# Validation F1-Score: 0.294643
# Validation Loss: 12.116160
#
# Epoch: 8/100
#
# Epoch: 8
# Train F1-Score: 0.330334
# Train Loss: 7.182566
# Validation F1-Score: 0.282724
# Validation Loss: 14.201779
#
# Epoch: 9/100
#
# Epoch: 9
# Train F1-Score: 0.330362
# Train Loss: 7.552791
# Validation F1-Score: 0.114776
# Validation Loss: 26.122507
#
# Epoch: 10/100
#
# Epoch: 10
# Train F1-Score: 0.346399
# Train Loss: 6.235160
# Validation F1-Score: 0.294643
# Validation Loss: 16.902534
#
# Epoch: 11/100
#
# Epoch: 11
# Train F1-Score: 0.327862
# Train Loss: 4.962590
# Validation F1-Score: 0.319496
# Validation Loss: 3.445366
#
# Epoch: 12/100
#
# Epoch: 12
# Train F1-Score: 0.346944
# Train Loss: 2.588599
# Validation F1-Score: 0.289593
# Validation Loss: 2.866350
#
# Epoch: 13/100
#
# Epoch: 13
# Train F1-Score: 0.361138
# Train Loss: 1.890831
# Validation F1-Score: 0.294643
# Validation Loss: 3.072498
#
# Epoch: 14/100
#
# Epoch: 14
# Train F1-Score: 0.333720
# Train Loss: 1.760952
# Validation F1-Score: 0.289193
# Validation Loss: 2.355024
#
# Epoch: 15/100
#
# Epoch: 15
# Train F1-Score: 0.343579
# Train Loss: 1.520873
# Validation F1-Score: 0.294643
# Validation Loss: 2.233770
#
# Epoch: 16/100
#
# Epoch: 16
# Train F1-Score: 0.382238
# Train Loss: 1.289065
# Validation F1-Score: 0.294643
# Validation Loss: 2.240645
#
# Epoch: 17/100
#
# Epoch: 17
# Train F1-Score: 0.379623
# Train Loss: 1.378708
# Validation F1-Score: 0.294643
# Validation Loss: 2.546743
#
# Epoch: 18/100
#
# Epoch: 18
# Train F1-Score: 0.358649
# Train Loss: 2.394044
# Validation F1-Score: 0.267123
# Validation Loss: 3.132159
#
# Epoch: 19/100
#
# Epoch: 19
# Train F1-Score: 0.351113
# Train Loss: 1.983484
# Validation F1-Score: 0.294643
# Validation Loss: 2.007478
#
# Epoch: 20/100
#
# Epoch: 20
# Train F1-Score: 0.351252
# Train Loss: 1.528889
# Validation F1-Score: 0.294643
# Validation Loss: 3.110604
#
# Epoch: 21/100
#
# Epoch: 21
# Train F1-Score: 0.347007
# Train Loss: 1.010164
# Validation F1-Score: 0.292975
# Validation Loss: 1.491635
#
# Epoch: 22/100
#
# Epoch: 22
# Train F1-Score: 0.341648
# Train Loss: 0.822529
# Validation F1-Score: 0.294294
# Validation Loss: 1.064540
#
# Epoch: 23/100
#
# Epoch: 23
# Train F1-Score: 0.366946
# Train Loss: 0.721465
# Validation F1-Score: 0.289193
# Validation Loss: 1.241605
#
# Epoch: 24/100
#
# Epoch: 24
# Train F1-Score: 0.395354
# Train Loss: 0.712310
# Validation F1-Score: 0.291291
# Validation Loss: 1.064238
#
# Epoch: 25/100
#
# Epoch: 25
# Train F1-Score: 0.318981
# Train Loss: 0.773726
# Validation F1-Score: 0.288786
# Validation Loss: 1.034693
#
# Epoch: 26/100
#
# Epoch: 26
# Train F1-Score: 0.358885
# Train Loss: 0.740174
# Validation F1-Score: 0.342913
# Validation Loss: 1.393739
#
# Epoch: 27/100
#
# Epoch: 27
# Train F1-Score: 0.370313
# Train Loss: 0.675319
# Validation F1-Score: 0.361845
# Validation Loss: 1.017398
#
# Epoch: 28/100
#
# Epoch: 28
# Train F1-Score: 0.393563
# Train Loss: 0.703082
# Validation F1-Score: 0.319250
# Validation Loss: 1.102412
#
# Epoch: 29/100
#
# Epoch: 29
# Train F1-Score: 0.374044
# Train Loss: 0.674095
# Validation F1-Score: 0.311296
# Validation Loss: 1.136059
#
# Epoch: 30/100
#
# Epoch: 30
# Train F1-Score: 0.360720
# Train Loss: 0.676290
# Validation F1-Score: 0.354072
# Validation Loss: 1.125552
#
# Epoch: 31/100
#
# Epoch: 31
# Train F1-Score: 0.366438
# Train Loss: 0.697338
# Validation F1-Score: 0.292975
# Validation Loss: 0.976115
#
# Epoch: 32/100
#
# Epoch: 32
# Train F1-Score: 0.357151
# Train Loss: 0.684711
# Validation F1-Score: 0.291291
# Validation Loss: 0.911307
#
# Epoch: 33/100
#
# Epoch: 33
# Train F1-Score: 0.397554
# Train Loss: 0.641481
# Validation F1-Score: 0.292975
# Validation Loss: 0.993647
#
# Epoch: 34/100
#
# Epoch: 34
# Train F1-Score: 0.373190
# Train Loss: 0.640055
# Validation F1-Score: 0.290909
# Validation Loss: 0.949652
#
# Epoch: 35/100
#
# Epoch: 35
# Train F1-Score: 0.379011
# Train Loss: 0.643451
# Validation F1-Score: 0.292975
# Validation Loss: 0.937475
#
# Epoch: 36/100
#
# Epoch: 36
# Train F1-Score: 0.356523
# Train Loss: 0.658175
# Validation F1-Score: 0.291291
# Validation Loss: 0.888264
#
# Epoch: 37/100
#
# Epoch: 37
# Train F1-Score: 0.337431
# Train Loss: 0.700422
# Validation F1-Score: 0.291291
# Validation Loss: 0.872932
#
# Epoch: 38/100
#
# Epoch: 38
# Train F1-Score: 0.372558
# Train Loss: 0.627929
# Validation F1-Score: 0.290909
# Validation Loss: 0.902043
#
# Epoch: 39/100
#
# Epoch: 39
# Train F1-Score: 0.326182
# Train Loss: 0.649979
# Validation F1-Score: 0.291291
# Validation Loss: 0.899018
#
# Epoch: 40/100
#
# Epoch: 40
# Train F1-Score: 0.362674
# Train Loss: 0.683332
# Validation F1-Score: 0.291291
# Validation Loss: 0.873629
#
# Epoch: 41/100
#
# Epoch: 41
# Train F1-Score: 0.387372
# Train Loss: 0.636536
# Validation F1-Score: 0.289593
# Validation Loss: 0.952108
#
# Epoch: 42/100
#
# Epoch: 42
# Train F1-Score: 0.327403
# Train Loss: 0.646034
# Validation F1-Score: 0.291291
# Validation Loss: 0.882766
#
# Epoch: 43/100
#
# Epoch: 43
# Train F1-Score: 0.348570
# Train Loss: 0.603149
# Validation F1-Score: 0.291291
# Validation Loss: 0.942128
#
# Epoch: 44/100
#
# Epoch: 44
# Train F1-Score: 0.360487
# Train Loss: 0.655348
# Validation F1-Score: 0.291291
# Validation Loss: 0.837124
#
# Epoch: 45/100
#
# Epoch: 45
# Train F1-Score: 0.364492
# Train Loss: 0.639639
# Validation F1-Score: 0.291291
# Validation Loss: 0.892239
#
# Epoch: 46/100
#
# Epoch: 46
# Train F1-Score: 0.393037
# Train Loss: 0.649167
# Validation F1-Score: 0.291291
# Validation Loss: 0.889204
#
# Epoch: 47/100
#
# Epoch: 47
# Train F1-Score: 0.355364
# Train Loss: 0.650971
# Validation F1-Score: 0.292975
# Validation Loss: 0.835953
#
# Epoch: 48/100
#
# Epoch: 48
# Train F1-Score: 0.392526
# Train Loss: 0.641190
# Validation F1-Score: 0.291291
# Validation Loss: 0.929648
#
# Epoch: 49/100
#
# Epoch: 49
# Train F1-Score: 0.331587
# Train Loss: 0.616469
# Validation F1-Score: 0.292975
# Validation Loss: 0.883348
#
# Epoch: 50/100
#
# Epoch: 50
# Train F1-Score: 0.334300
# Train Loss: 0.670149
# Validation F1-Score: 0.291291
# Validation Loss: 0.903112
#
# Epoch: 51/100
#
# Epoch: 51
# Train F1-Score: 0.341581
# Train Loss: 0.663049
# Validation F1-Score: 0.289593
# Validation Loss: 0.933616
#
# Epoch: 52/100
#
# Epoch: 52
# Train F1-Score: 0.365563
# Train Loss: 0.657167
# Validation F1-Score: 0.291291
# Validation Loss: 0.843460
#
# Epoch: 53/100
#
# Epoch: 53
# Train F1-Score: 0.390693
# Train Loss: 0.612144
# Validation F1-Score: 0.289593
# Validation Loss: 0.957420
#
# Epoch: 54/100
#
# Epoch: 54
# Train F1-Score: 0.365166
# Train Loss: 0.623883
# Validation F1-Score: 0.291291
# Validation Loss: 0.879576
#
# Epoch: 55/100
#
# Epoch: 55
# Train F1-Score: 0.389029
# Train Loss: 0.626921
# Validation F1-Score: 0.291291
# Validation Loss: 0.925152
#
# Epoch: 56/100
#
# Epoch: 56
# Train F1-Score: 0.348889
# Train Loss: 0.624113
# Validation F1-Score: 0.289593
# Validation Loss: 0.917739
#
# Epoch: 57/100
#
# Epoch: 57
# Train F1-Score: 0.355689
# Train Loss: 0.670955
# Validation F1-Score: 0.291291
# Validation Loss: 0.923940
#
# Epoch: 58/100
#
# Epoch: 58
# Train F1-Score: 0.363474
# Train Loss: 0.634659
# Validation F1-Score: 0.291291
# Validation Loss: 0.875509
#
# Epoch: 59/100
#
# Epoch: 59
# Train F1-Score: 0.405713
# Train Loss: 0.644976
# Validation F1-Score: 0.291291
# Validation Loss: 0.849056
#
# Epoch: 60/100
#
# Epoch: 60
# Train F1-Score: 0.378143
# Train Loss: 0.618667
# Validation F1-Score: 0.291291
# Validation Loss: 0.996749
#
# Epoch: 61/100
#
# Epoch: 61
# Train F1-Score: 0.413226
# Train Loss: 0.692834
# Validation F1-Score: 0.289593
# Validation Loss: 0.912537
#
# Epoch: 62/100
#
# Epoch: 62
# Train F1-Score: 0.345137
# Train Loss: 0.644621
# Validation F1-Score: 0.291291
# Validation Loss: 0.879285
#
# Epoch: 63/100
#
# Epoch: 63
# Train F1-Score: 0.303066
# Train Loss: 0.654313
# Validation F1-Score: 0.291291
# Validation Loss: 0.842668
#
# Epoch: 64/100
#
# Epoch: 64
# Train F1-Score: 0.354559
# Train Loss: 0.647603
# Validation F1-Score: 0.291291
# Validation Loss: 0.897634
#
# Epoch: 65/100
# Epoch: 65
# Train F1-Score: 0.418821
# Train Loss: 0.656398
# Validation F1-Score: 0.289593
# Validation Loss: 0.845399
#
# Epoch: 66/100
#
# Epoch: 66
# Train F1-Score: 0.357277
# Train Loss: 0.649571
# Validation F1-Score: 0.289593
# Validation Loss: 0.915798
#
# Epoch: 67/100
#
# Epoch: 67
# Train F1-Score: 0.376559
# Train Loss: 0.640034
# Validation F1-Score: 0.291291
# Validation Loss: 0.857679
#
# Epoch: 68/100
#
# Epoch: 68
# Train F1-Score: 0.339300
# Train Loss: 0.670517
# Validation F1-Score: 0.291291
# Validation Loss: 0.880952
#
# Epoch: 69/100
#
# Epoch: 69
# Train F1-Score: 0.344240
# Train Loss: 0.649257
# Validation F1-Score: 0.291291
# Validation Loss: 0.897259
#
# Epoch: 70/100
#
# Epoch: 70
# Train F1-Score: 0.324683
# Train Loss: 0.635283
# Validation F1-Score: 0.292975
# Validation Loss: 0.847681
#
# Epoch: 71/100
#
# Epoch: 71
# Train F1-Score: 0.373396
# Train Loss: 0.656868
# Validation F1-Score: 0.291291
# Validation Loss: 0.925051
#
# Epoch: 72/100
#
# Epoch: 72
# Train F1-Score: 0.374412
# Train Loss: 0.647585
# Validation F1-Score: 0.289593
# Validation Loss: 0.969335
#
# Epoch: 73/100
#
# Epoch: 73
# Train F1-Score: 0.381855
# Train Loss: 0.626747
# Validation F1-Score: 0.291291
# Validation Loss: 0.845907
#
# Epoch: 74/100
#
# Epoch: 74
# Train F1-Score: 0.380351
# Train Loss: 0.621132
# Validation F1-Score: 0.291291
# Validation Loss: 0.874154
#
# Epoch: 75/100
#
# Epoch: 75
# Train F1-Score: 0.368186
# Train Loss: 0.629597
# Validation F1-Score: 0.291291
# Validation Loss: 0.879847
#
# Epoch: 76/100
#
# Epoch: 76
# Train F1-Score: 0.381417
# Train Loss: 0.651687
# Validation F1-Score: 0.291291
# Validation Loss: 0.850627
#
# Epoch: 77/100
#
# Epoch: 77
# Train F1-Score: 0.361227
# Train Loss: 0.721921
# Validation F1-Score: 0.292975
# Validation Loss: 0.973080
#
# Epoch: 78/100
#
# Epoch: 78
# Train F1-Score: 0.376075
# Train Loss: 0.630037
# Validation F1-Score: 0.289593
# Validation Loss: 0.937699
#
# Epoch: 79/100
#
# Epoch: 79
# Train F1-Score: 0.333483
# Train Loss: 0.630198
# Validation F1-Score: 0.291291
# Validation Loss: 0.880053
#
# Epoch: 80/100
#
# Epoch: 80
# Train F1-Score: 0.374725
# Train Loss: 0.629478
# Validation F1-Score: 0.289593
# Validation Loss: 0.848828
#
# Epoch: 81/100
#
# Epoch: 81
# Train F1-Score: 0.343315
# Train Loss: 0.659604
# Validation F1-Score: 0.291291
# Validation Loss: 0.854402
#
# Epoch: 82/100
#
# Epoch: 82
# Train F1-Score: 0.375204
# Train Loss: 0.630602
# Validation F1-Score: 0.291291
# Validation Loss: 0.818826
#
# Epoch: 83/100
#
# Epoch: 83
# Train F1-Score: 0.344118
# Train Loss: 0.625655
# Validation F1-Score: 0.291291
# Validation Loss: 0.871395
#
# Epoch: 84/100
#
# Epoch: 84
# Train F1-Score: 0.384748
# Train Loss: 0.697132
# Validation F1-Score: 0.289593
# Validation Loss: 0.872568
#
# Epoch: 85/100
#
# Epoch: 85
# Train F1-Score: 0.336550
# Train Loss: 0.670681
# Validation F1-Score: 0.291291
# Validation Loss: 0.884683
#
# Epoch: 86/100
#
# Epoch: 86
# Train F1-Score: 0.329904
# Train Loss: 0.654402
# Validation F1-Score: 0.292975
# Validation Loss: 0.944088
#
# Epoch: 87/100
#
# Epoch: 87
# Train F1-Score: 0.365775
# Train Loss: 0.662757
# Validation F1-Score: 0.289593
# Validation Loss: 0.908331
#
# Epoch: 88/100
#
# Epoch: 88
# Train F1-Score: 0.367622
# Train Loss: 0.659584
# Validation F1-Score: 0.291291
# Validation Loss: 0.876315
#
# Epoch: 89/100
#
# Epoch: 89
# Train F1-Score: 0.359498
# Train Loss: 0.639366
# Validation F1-Score: 0.291291
# Validation Loss: 0.816867
#
# Epoch: 90/100
#
# Epoch: 90
# Train F1-Score: 0.365253
# Train Loss: 0.633901
# Validation F1-Score: 0.291291
# Validation Loss: 0.883127
#
# Epoch: 91/100
#
# Epoch: 91
# Train F1-Score: 0.358479
# Train Loss: 0.659884
# Validation F1-Score: 0.291291
# Validation Loss: 0.927494
#
# Epoch: 92/100
#
# Epoch: 92
# Train F1-Score: 0.356220
# Train Loss: 0.653479
# Validation F1-Score: 0.291291
# Validation Loss: 0.963397
#
# Epoch: 93/100
#
# Epoch: 93
# Train F1-Score: 0.356177
# Train Loss: 0.643479
# Validation F1-Score: 0.291291
# Validation Loss: 0.867132
#
# Epoch: 94/100
#
# Epoch: 94
# Train F1-Score: 0.364084
# Train Loss: 0.691478
# Validation F1-Score: 0.291291
# Validation Loss: 0.903109
#
# Epoch: 95/100
#
# Epoch: 95
# Train F1-Score: 0.373484
# Train Loss: 0.654582
# Validation F1-Score: 0.291291
# Validation Loss: 0.861007
#
# Epoch: 96/100
#
# Epoch: 96
# Train F1-Score: 0.387820
# Train Loss: 0.602278
# Validation F1-Score: 0.292975
# Validation Loss: 0.958304
#
# Epoch: 97/100
#
# Epoch: 97
# Train F1-Score: 0.358538
# Train Loss: 0.632762
# Validation F1-Score: 0.291291
# Validation Loss: 0.905949
#
# Epoch: 98/100
#
# Epoch: 98
# Train F1-Score: 0.331214
# Train Loss: 0.634771
# Validation F1-Score: 0.291291
# Validation Loss: 0.887866
#
# Epoch: 99/100
#
# Epoch: 99
# Train F1-Score: 0.333832
# Train Loss: 0.642346
# Validation F1-Score: 0.291291
# Validation Loss: 0.846279
#
# Epoch: 100/100
#
# Epoch: 100
# Train F1-Score: 0.368801
# Train Loss: 0.629970
# Validation F1-Score: 0.290909
# Validation Loss: 0.904810
